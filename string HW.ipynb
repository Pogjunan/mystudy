# %% [markdown]
# # HW : 0315
# ### 1. 적당한 인덱싱을 통하여 출력결과가 아래와 같도록 하라.

# %%
a='Jeonbuk National University'

# %% [markdown]
# <head> 위의 a 를 University 로 바꾸어야합니다.</head>
# <br>
# <br>
# __그러기위해서는 앞부터 세는 것보다 뒤부터 세는 것이 효율적일 것입니다.__

# %%
a[-10:]
# Out:
# 'University'

# %% [markdown]
# ### 2. 출력결과가 아래와 같도록 하는 코드를 작성하라. (lower 함수를 이용할 것)

# %% [markdown]
# 위 그대로 a 식을 lower 함수를 적용해도 아래와 같이 나올 것입니다.
# <br>
# <br>
#
# 의도를 보았을 때 모든 알파벳을 대문자로 쓰는 것일 수도 있고 어떤 경우든 상관 없을 것입니다.
# <br>
# <br>
#
# 따라서 a 식을 그대로 사용하겠습니다.

# %%
a.lower()
# Out:
# 'jeonbuk national university'

# %% [markdown]
# ### 3. 아래의 코드를 관찰하고 isupper()의 기능이 무엇인지 스스로 정리해보라.
#
# - A 는 모두 대문자이고
#  - AA 도 모두 대문자이다.
#  - 그러나 Aa 는 모두 대문자가 아니다.
#  - 그리고 aa 도 모두 대문자가 아니다.
#  - aA 도 모두 대문자가 아니다.
#
# ### 처음에는 a 와 A 에 어떤 변수가 들어가있는줄 알고 약간 헤맸습니다만 일반적인 그냥 string 이라는 것을 알았습니다..
#
# ### 따라서 isupper() 은 대문자 판별 함수입니다. 유추한 기능이 맞는지 chatGPT 에게 물어보겠습니다.

# %% [markdown]
# ![image.png](attachment:204100d3-81b1-4f27-ae20-3bde15994d0d.png)

# %% [markdown]
# chat gpt 는 결국 'string are uppercase letters or not' 이라는 문장으로
# <br>대문자를 구별한다는 기능을 한다고 말하였습니다.
# <br>
# <br>( 값을 boolean 유형(True,False)으로 분류하는 것또한 의미가 있습니다.)

# %% [markdown]
# ### 4.다음 중 실행 불가능한 코드를 모두 골라라.

# %% [markdown]
# (b) 와 (c)가 실행이 불가능할 것으로 예측됩니다. 제 개념이 확실하지 않을 수 있으니 직접 코드로 확인해보겠습니다.

# %%
'a'*2
# Out:
# 'aa'

# %%
'a'*'2'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7440\2481534813.py in <module>
# ----> 1 'a'*'2'
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
'a'+2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7440\197187164.py in <module>
# ----> 1 'a'+2
#
# TypeError: can only concatenate str (not "int") to str

# %%
'a'+'2'
# Out:
# 'a2'

# %% [markdown]
# ## 정답은 (b) , (c) 입니다.
